# %% [markdown]
# # NewsMorph — Fine-tune the Fake News Detector
# Run this notebook in Google Colab with a GPU runtime. It downloads WELFake, fine-tunes DistilBERT, evaluates it, and saves the trained model.

# %%
# !git clone https://github.com/ankit-9335/fake-news-generator-and-detector.git
# %cd fake-news-generator-and-detector
# !pip install -q -r training/requirements-train.txt

# %%
# !python training/train_detector.py

# %% [markdown]
# ## After training
# The model will be in `newsmorph-fake-news-detector/`. Upload that folder to a Hugging Face model repository, then set `NEWSMORPH_MODEL_ID` in Streamlit to that repository.
